# %% [markdown]
# # Task 2
# This week you have learnt about various types of ML models. <br>
# Let us focus on two of them.

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Instructions
# 1. create a folder called synapse_w2 in your drive
# 2. add housing_data.csv, classified_data.txt, titanic_data.csv in the folder.
# 3. You will use the data from this path in this notebook

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data_df = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/housing_data.csv")
titanic_data_df = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/titanic_data.csv")
classified_data_df = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/classified_data.txt")

# %% [markdown]
# # 1)  Linear Regression on Housing Price

# %% [markdown]
# ### Import packages and dataset

# %%
# import numpy, pandas, matplotlib, seaborn
# add code here
# %matplotlib inline

# %% [markdown]
# **Read housing_data.csv using pandas and call head() to show first few records.**

# %%
# add code here
housing_data_df.head()
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3      63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4      59982.197226  ...                         USNS Raymond\nFPO AE 09386
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Exloratory Data Analysis (EDA)

# %% [markdown]
# **'info()' method to check the data types and number**

# %%
# add code here
housing_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %% [markdown]
# **Get the statistical summary of the data set** <br>
# Hint: describe()

# %%
# add code here
housing_data_df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  ...  Area Population         Price
# count       5000.000000          5000.000000  ...      5000.000000  5.000000e+03
# mean       68583.108984             5.977222  ...     36163.516039  1.232073e+06
# std        10657.991214             0.991456  ...      9925.650114  3.531176e+05
# min        17796.631190             2.644304  ...       172.610686  1.593866e+04
# 25%        61480.562388             5.322283  ...     29403.928702  9.975771e+05
# 50%        68804.286404             5.970429  ...     36199.406689  1.232669e+06
# 75%        75783.338666             6.650808  ...     42861.290769  1.471210e+06
# max       107701.748378             9.519088  ...     69621.713378  2.469066e+06
#
# [8 rows x 6 columns]

# %% [markdown]
# **Print the names of the columns(features)**

# %%
# add code here
for i in housing_data_df.columns:
  print(i)
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price
# Address

# %% [markdown]
# ### Basic plotting and visualization

# %% [markdown]
# **The target quantity is price. Let us see its distribution.** <br>
# Plot a histogram of Price. Choose the number of bins by experimenting a little. (Expected: a bell curve shape)

# %%
# add code here
a = housing_data_df["Price"] 
b = 25
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a, bins = b)
plt.show()

# %% [markdown]
# **Let us see how the different features are correlated with each other by printing a Correlation Matrix**<br>
# Hint: corr()

# %%
# add code here
housing_data_df.corr()
# Out:
#                               Avg. Area Income  ...     Price
# Avg. Area Income                      1.000000  ...  0.639734
# Avg. Area House Age                  -0.002007  ...  0.452543
# Avg. Area Number of Rooms            -0.011032  ...  0.335664
# Avg. Area Number of Bedrooms          0.019788  ...  0.171071
# Area Population                      -0.016234  ...  0.408556
# Price                                 0.639734  ...  1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# ### Feature and variable sets

# %% [markdown]
# **Make a list of data frame column names**
# **Create a new dataframe containing all the numerical training features(note that Address is a string so ignore that) and store it in a variable called "X"**<br><br>
# **Then create a new dataframe containing the target (Price) and store it in a variable called "y"**

# %%
# add code here
lst = housing_data_df.columns
lst
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
# This code should print (5000, 5) and (5000,) if everything is correct
X = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/housing_data.csv")
X.drop(["Price", "Address"], axis=1, inplace=True)
X
# Out:
#       Avg. Area Income  ...  Area Population
# 0         79545.458574  ...     23086.800503
# 1         79248.642455  ...     40173.072174
# 2         61287.067179  ...     36882.159400
# 3         63345.240046  ...     34310.242831
# 4         59982.197226  ...     26354.109472
# ...                ...  ...              ...
# 4995      60567.944140  ...     22837.361035
# 4996      78491.275435  ...     25616.115489
# 4997      63390.686886  ...     33266.145490
# 4998      68001.331235  ...     42625.620156
# 4999      65510.581804  ...     46501.283803
#
# [5000 rows x 5 columns]

# %%
Y = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/housing_data.csv")
Y.drop(["Avg. Area Income","Avg. Area House Age","Avg. Area Number of Rooms","Avg. Area Number of Bedrooms","Area Population","Address"], axis=1, inplace=True)
Y
# Out:
#              Price
# 0     1.059034e+06
# 1     1.505891e+06
# 2     1.058988e+06
# 3     1.260617e+06
# 4     6.309435e+05
# ...            ...
# 4995  1.060194e+06
# 4996  1.482618e+06
# 4997  1.030730e+06
# 4998  1.198657e+06
# 4999  1.298950e+06
#
# [5000 rows x 1 columns]

# %%
# print a few record of X
# add code here
X.head()
# Out:
#    Avg. Area Income  ...  Area Population
# 0      79545.458574  ...     23086.800503
# 1      79248.642455  ...     40173.072174
# 2      61287.067179  ...     36882.159400
# 3      63345.240046  ...     34310.242831
# 4      59982.197226  ...     26354.109472
#
# [5 rows x 5 columns]

# %%
# print a few record of y
# add code here
Y.head()
# Out:
#           Price
# 0  1.059034e+06
# 1  1.505891e+06
# 2  1.058988e+06
# 3  1.260617e+06
# 4  6.309435e+05

# %% [markdown]
# ### Test-train split

# %% [markdown]
# **Import train_test_split function from scikit-learn**

# %%
# add code here
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Create X and y train and test splits in one command using a test size of 0.3 and a random seed**<br>
# They should be called X_train, X_test, y_train, y_test

# %%
# add code here
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42) #random-state=123

# %% [markdown]
# **Print the size and shape of each of the train/test splits (it should be in the ratio as per test_size parameter above)**

# %%
# add code here
print("size and shape of X_train: ",X_train.size, X_train.shape)
print("size and shape of X_test: ",X_test.size, X_test.shape)
print("size and shape of y_train: ",y_train.size, y_train.shape)
print("size and shape of y_test: ",y_test.size, y_test.shape)
# Out:
# size and shape of X_train:  17500 (3500, 5)
# size and shape of X_test:  7500 (1500, 5)
# size and shape of y_train:  3500 (3500, 1)
# size and shape of y_test:  1500 (1500, 1)

# %% [markdown]
# ### Model fit and training

# %% [markdown]
# **Import LinearRegression and metrics from scikit-learn**

# %%
# add code for imports here
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# Create a Linear Regression object 'lm' by calling LinearRegression()
# add code here
lm = LinearRegression()

# %% [markdown]
# **Fit the model on to the instantiated object itself using the X_train and y_train created earlier. No need to create another variable**<br>
# Hint: lm.fit()

# %%
# add code here
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Prediction, error estimate, and regression evaluation matrices

# %% [markdown]
# **Prediction using the lm model**<br>
# Use model.predict() on X_test and store them in a variable called "predictions".<br>
# Print type and size of the predictions. Size should be (1500,) if everything is correct.

# %%
# add code here
predictions = lm.predict(X_test)
print(type(predictions), predictions.size)
# Out:
# <class 'numpy.ndarray'> 1500

# %% [markdown]
# **Since we're done with our predictions, let's compare it with y_test and see how accurate our predictions are.<br> Plot a Scatter plot of predicted price and y_test set to see if the data fall on a 45 degree straight line**

# %%
# add code here
plt.figure(figsize=(10,10))
plt.scatter(y=predictions, x=y_test) 
plt.show()

# %% [markdown]
# **Print the R-square value and round it to 3 decimal places**<br>
# Hint: sklearn metrics.r2_score

# %%
# add code here
from sklearn.metrics import r2_score
print(f'r2 score: {r2_score(y_test, predictions):.3f}')
# Out:
# r2 score: 0.915

# %% [markdown]
# # 2) K-nearest neighbor Classification

# %% [markdown]
# ### Import packages and dataset

# %%
# import numpy, pandas, matplotlib, seaborn
# add code here
import numpy as np
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Read classified_data.txt using pandas and call head() to show first few records. Call this dataframe "df"** <br>
# Use "index_col" parameter to index the dataframe according to the first column. Otherwise, a new column would get created.

# %%
# add code here
df = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/classified_data.txt", index_col=[0])
df.head()
# Out:
#         WTT       PTI       EQW  ...       HQE       NXJ  TARGET CLASS
# 0  0.913917  1.162073  0.567946  ...  0.879422  1.231409             1
# 1  0.635632  1.003722  0.535342  ...  0.621552  1.492702             0
# 2  0.721360  1.201493  0.921990  ...  0.957877  1.285597             0
# 3  1.234204  1.386726  0.653046  ...  1.522692  1.153093             1
# 4  1.279491  0.949750  0.627280  ...  1.463812  1.419167             1
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Exloratory Data Analysis (EDA)

# %% [markdown]
# **'info()' method to check the data types and number**

# %%
# add code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WTT           1000 non-null   float64
#  1   PTI           1000 non-null   float64
#  2   EQW           1000 non-null   float64
#  3   SBI           1000 non-null   float64
#  4   LQE           1000 non-null   float64
#  5   QWG           1000 non-null   float64
#  6   FDJ           1000 non-null   float64
#  7   PJF           1000 non-null   float64
#  8   HQE           1000 non-null   float64
#  9   NXJ           1000 non-null   float64
#  10  TARGET CLASS  1000 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 93.8 KB

# %% [markdown]
# **Get the statistical summary of the data set** <br>
# Hint: describe()

# %%
# add code here
df.describe()
# Out:
#                WTT          PTI  ...          NXJ  TARGET CLASS
# count  1000.000000  1000.000000  ...  1000.000000    1000.00000
# mean      0.949682     1.114303  ...     1.362725       0.50000
# std       0.289635     0.257085  ...     0.204225       0.50025
# min       0.174412     0.441398  ...     0.639693       0.00000
# 25%       0.742358     0.942071  ...     1.222623       0.00000
# 50%       0.940475     1.118486  ...     1.375368       0.50000
# 75%       1.163295     1.307904  ...     1.504832       1.00000
# max       1.721779     1.833757  ...     1.893950       1.00000
#
# [8 rows x 11 columns]

# %% [markdown]
# ### Check the spread of the features

# %% [markdown]
# **Store the column names in a list**

# %%
# add code here
ls=[]
lsc=[]
for i in df.columns:
  ls.append(i)
  lsc.append(i)
# ls.remove('Unnamed: 0') 
lsc.remove('TARGET CLASS')
print(ls)
n = len(ls)
print(n)
# Out:
# ['WTT', 'PTI', 'EQW', 'SBI', 'LQE', 'QWG', 'FDJ', 'PJF', 'HQE', 'NXJ', 'TARGET CLASS']
# 11

# %% [markdown]
# **Run a 'for' loop to draw boxplots of all the features for '0' and '1' TARGET CLASS**<br>
# Hint: Loop through each of the 10 features and draw a separate boxplot. You should have 10 boxplots in total. <br>
# Refer seaborn boxplot()

# %%
# add code here
features= ls[:-1]
for i in features:
  plt.figure(figsize = (10, 10))
  sns.boxplot(data=df, x='TARGET CLASS', y=i)
  plt.show()

# %% [markdown]
# ### Standardize the features using sklearn.preprocessing
# Why should we standardize?<br>
# Variables that are measured at different scales do not contribute equally to the model fitting & model learned function and might end up creating a bias. Thus, to deal with this potential problem feature-wise standardized (μ=0, σ=1) is usually used prior to model fitting.<br>
# <br>
# Go through this link for a better understanding:<br>
# https://towardsdatascience.com/how-and-why-to-standardize-your-data-996926c2c832

# %% [markdown]
# **import StandardScaler from Sklearn and instantiate it to a variable called "scaler"**

# %%
# add code here
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# **Fit only the features data to this scaler (leaving the TARGET CLASS column out) and then transform**<br>
# Hint: scaler.fit() and scaler.transform()

# %%
# add code here
# for i in range(n):
sample_df = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/classified_data.txt", index_col=False)
sample_df.drop('TARGET CLASS', inplace=True, axis=1)
sample_df.drop('Unnamed: 0', inplace=True, axis=1)
sample_df.head()
# Out:
#         WTT       PTI       EQW  ...       PJF       HQE       NXJ
# 0  0.913917  1.162073  0.567946  ...  0.643798  0.879422  1.231409
# 1  0.635632  1.003722  0.535342  ...  1.013546  0.621552  1.492702
# 2  0.721360  1.201493  0.921990  ...  1.154483  0.957877  1.285597
# 3  1.234204  1.386726  0.653046  ...  1.380003  1.522692  1.153093
# 4  1.279491  0.949750  0.627280  ...  0.646691  1.463812  1.419167
#
# [5 rows x 10 columns]

# %%
a = scaler.fit(sample_df)

# %%
b = a.transform(sample_df)
b
# Out:
# array([[-0.12354188,  0.18590747, -0.91343069, ..., -1.48236813,
#         -0.9497194 , -0.64331425],
#        [-1.08483602, -0.43034845, -1.02531333, ..., -0.20224031,
#         -1.82805088,  0.63675862],
#        [-0.78870217,  0.33931821,  0.30151137, ...,  0.28570652,
#         -0.68249379, -0.37784986],
#        ...,
#        [ 0.64177714, -0.51308341, -0.17920486, ..., -2.36249443,
#         -0.81426092,  0.11159651],
#        [ 0.46707241, -0.98278576, -1.46519359, ..., -0.03677699,
#          0.40602453, -0.85567   ],
#        [-0.38765353, -0.59589427, -1.4313981 , ..., -0.56778932,
#          0.3369971 ,  0.01034996]])

# %% [markdown]
# **Scaler.transform() will return an array. We need to convert this into a dataframe. Do this and add the column names to the dataframe. Call this new dataframe as "df_feat". Call head() on this df**<br>
# Note: The final dataframe will have the initial columns except the "TARGET CLASS".

# %%
# add code here
df_feat = pd.DataFrame(b)
df_feat.columns = ['WTT', 'PTI', 'EQW', 'SBI', 'LQE', 'QWG', 'FDJ', 'PJF', 'HQE', 'NXJ']
df_feat.head()
# Out:
#         WTT       PTI       EQW  ...       PJF       HQE       NXJ
# 0 -0.123542  0.185907 -0.913431  ... -1.482368 -0.949719 -0.643314
# 1 -1.084836 -0.430348 -1.025313  ... -0.202240 -1.828051  0.636759
# 2 -0.788702  0.339318  0.301511  ...  0.285707 -0.682494 -0.377850
# 3  0.982841  1.060193 -0.621399  ...  1.066491  1.241325 -1.026987
# 4  1.139275 -0.640392 -0.709819  ... -1.472352  1.040772  0.276510
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Train/Test split

# %% [markdown]
# **Set X to be equal to df_feat and set y accordingly. As you know, X contains our training features and y contains our target.**<br>
# Hint: y can be taken directly from the initaial dataframe "df"

# %%
# add code here
x = df_feat
x
# Out:
#           WTT       PTI       EQW  ...       PJF       HQE       NXJ
# 0   -0.123542  0.185907 -0.913431  ... -1.482368 -0.949719 -0.643314
# 1   -1.084836 -0.430348 -1.025313  ... -0.202240 -1.828051  0.636759
# 2   -0.788702  0.339318  0.301511  ...  0.285707 -0.682494 -0.377850
# 3    0.982841  1.060193 -0.621399  ...  1.066491  1.241325 -1.026987
# 4    1.139275 -0.640392 -0.709819  ... -1.472352  1.040772  0.276510
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.211653 -0.312490  0.065163  ... -2.604264 -0.139347 -0.069602
# 996 -1.292453 -0.616901  0.369613  ... -1.242110 -0.679746  1.473448
# 997  0.641777 -0.513083 -0.179205  ... -2.362494 -0.814261  0.111597
# 998  0.467072 -0.982786 -1.465194  ... -0.036777  0.406025 -0.855670
# 999 -0.387654 -0.595894 -1.431398  ... -0.567789  0.336997  0.010350
#
# [1000 rows x 10 columns]

# %%
dqrf = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/classified_data.txt", index_col=[0])
# Y.drop(lsc, axis=1, inplace=True)
# Y.drop(['Unnamed: 0'], axis=1, inplace=True)
# Y
Y=dqrf['TARGET CLASS']
Y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    1
# Name: TARGET CLASS, Length: 1000, dtype: int64

# %% [markdown]
# **Import train_test_split function from scikit-learn**<br>
# **Create X and y train and test splits in one command using a test size of 0.3 and a random seed**<br>
# They should be called X_train, X_test, y_train, y_test

# %%
# add code here
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size=0.3, random_state=42) #random_state=101

# %% [markdown]
# ### Model fit and training

# %% [markdown]
# **import KNeighborsClassifier from sklearn and initialize it with neighbours = 1. Fit this on X_train and y_train**

# %%
# add code here
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=1)
fitted_model = classifier.fit(x_train, Y_train)

# %% [markdown]
# **Using this fitted model, predict on X_test. Store these predictions in variable called pred.**

# %%
# add code here
pred = fitted_model.predict(x_test)

# %% [markdown]
# **Let us check how correct these predictions are.<br>
# Print a classification report of y_test and pred**<br>
# Hint: sklearn classification_report

# %%
# add code here
from sklearn.metrics import classification_report
d=classification_report(Y_test, pred, output_dict=True)
print(d)
# Out:
# {'0': {'precision': 0.9241379310344827, 'recall': 0.9436619718309859, 'f1-score': 0.9337979094076655, 'support': 142}, '1': {'precision': 0.9483870967741935, 'recall': 0.930379746835443, 'f1-score': 0.939297124600639, 'support': 158}, 'accuracy': 0.9366666666666666, 'macro avg': {'precision': 0.9362625139043381, 'recall': 0.9370208593332144, 'f1-score': 0.9365475170041522, 'support': 300}, 'weighted avg': {'precision': 0.9369091583240636, 'recall': 0.9366666666666666, 'f1-score': 0.9366941627426316, 'support': 300}}

# %% [markdown]
# **Print the accuracy using numpy and round it to 3 decimal places.**

# %%
# add code here
# acc = (float)(d['accuracy'])
# print('{0:.3f}'.format(acc))
acc = np.sum(pred==Y_test)/len(pred)
print('{0:.3f}'.format(acc))
# Out:
# 0.937

# %% [markdown]
# ### Choosing optimal 'k'

# %% [markdown]
# **Above, we chose n_neighbours to be equal to 1. Choosing a small value of K leads to unstable decision boundaries. <br>
# We need to select n_neighbours by calculating the accuracy for every value of n from 1 to 60 and then choosing the one which gives the highest accuracy.**

# %%
# Do the same as we did above, but this time make a loop from n = 1 to n = 60 and append the accuracy
# for each in a list
k_list = []
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
for i in range(1,61):
  classify = KNeighborsClassifier(n_neighbors=i)
  fit_model = classify.fit(x_train, Y_train)
  predict = fit_model.predict(x_test)
  t=classification_report(Y_test, predict, output_dict=True)
  # accu = (float)(t['accuracy'])
  accu =( (np.sum(predict==Y_test))/len(predict) )
  k_list.append(accu)
# add code here

# %% [markdown]
# **Plot a graph of K value vs Accuracy**

# %%
# add code here
a_list = list(range(1, 61))
plt.figure(figsize=(10,6))
plt.plot(a_list,k_list)
plt.xlabel("K-Value", fontsize = 20)
plt.ylabel("Testing Accuracy", fontsize = 20)
plt.show()

# %% [markdown]
# **Choose the best value of n_neighbours and give a reason why and also print the accuracy**

# %%
# add code here 
# For K-Value between 12-17, Accuracy is same for all of them and its the highest among 1-60. 
# Lower value of K will make model more complex unnecessarily. This might become a case of overfitting the data.
# Also the model is not too much computationally expensive even for higher values. As we increase the number of neighbors, the model starts to generalize well.
# So i thought of using a higher value of k taking into account a good accuracy. 
# So I feel n_neighbors=17 could be an optimal value.
print("Best value of n_neighbours = 17 & corresponding accuracy is:",k_list[16])
# Out:
# Best value of n_neighbours = 17 & corresponding accuracy is: 0.9533333333333334

# %% [markdown]
# # 3). Decision Tree Classifier

# %% [markdown]
# <b>read the titanic_data.csv using pandas and show the dataframe</b>

# %%
#write code here
titanic_data_df2 = pd.read_csv("/content/gdrive/My Drive/Synapse_LP/synapse_w2/synapse_w2/titanic_data.csv")
titanic_data_df2
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# <b>Write a function which accepts a dataframe, preprocesses the data (use task 1 notebook) and returns a new dataframe. </b> <br>
# you may need a helper function for normalizing data so feel free to define that as well

# %%
import re

def normalize(data_list):
  X_new = []
  X_max = max(data_list)
  X_min = min(data_list)
  for i in data_list:
    X_new.append( (i - X_min)/(X_max - X_min) )
  return X_new

def titanic_preprocessing_pipeline(df):
  #enter preprocessing steps as done in task 1
  #make sure the preprocessed dataframe looks like the output in task 1
  #return the dataframe
  title_list = []
  for i in df["Name"]:
    title_search = re.search('(\w+)\.', i)
    if title_search:
      title = title_search.group(1)
      title_list.append(title)
  df["Title"] = title_list
  df = df.drop(["PassengerId", "Ticket", "Name"], axis=1, inplace=False)
  df = df.drop(["Cabin"], axis=1, inplace=False)
  df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0], inplace=False) 
  df["Age"] = df["Age"].fillna(df["Age"].mean(), inplace=False)
  df["Family_members"] = df["SibSp"] + df["Parch"]
  df = df.drop(["SibSp", "Parch"], axis=1, inplace=False)
  df["Age"] = normalize(df["Age"])
  df["Fare"] = normalize(df["Fare"])
  df["Family_members"] = normalize(df["Family_members"])
  df = pd.get_dummies(df, columns=["Pclass", "Sex", "Title", "Embarked"])
  return df

# %%
done2_df = titanic_preprocessing_pipeline(titanic_data_df2)
done2_df
# Out:
#      Survived       Age      Fare  ...  Embarked_C  Embarked_Q  Embarked_S
# 0           0  0.271174  0.014151  ...           0           0           1
# 1           1  0.472229  0.139136  ...           1           0           0
# 2           1  0.321438  0.015469  ...           0           0           1
# 3           1  0.434531  0.103644  ...           0           0           1
# 4           0  0.434531  0.015713  ...           0           0           1
# ..        ...       ...       ...  ...         ...         ...         ...
# 886         0  0.334004  0.025374  ...           0           0           1
# 887         1  0.233476  0.058556  ...           0           0           1
# 888         0  0.367921  0.045771  ...           0           0           1
# 889         1  0.321438  0.058556  ...           1           0           0
# 890         0  0.396833  0.015127  ...           0           1           0
#
# [891 rows x 29 columns]

# %% [markdown]
# <b>extract the y label (survived) from the dataframe and store it in a new variable</b>

# %%
ns = done2_df['Survived'] 
ns
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# <b>remove the y_label (survived) from the dataframe</b>

# %%
done2_df.drop(["Survived"], axis=1, inplace=True)

# %% [markdown]
# <b>Split the data into train and test. (do a split in the ratio 30:70)</b>

# %%
from sklearn.model_selection import train_test_split
c_train, c_test, v_train, v_test = train_test_split(done2_df, ns, test_size=0.3, random_state=42)

# %% [markdown]
# <b>Now that you have the entire preprocessed and split data, implement the decision tree algorithm from sklearn and fit it to this dataset</b> <br>
#
# Make sure that you play with the hyperparameters to get a good result. You can even use bagging and boosting methods like random forest or adaboost to improve your accuracy. Visualize results, try different hyperparameters by using a loop, GET CREATIVE!<br>
#
# Machine learning is an iteritive process. You will have to keep playing with hyperparameters and algorithms. No fixed algorithm will work on a fixed dataset.
#
# Take this up as a challenge. The person with the best accuracy wins the round!

# %%
import re
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier

def populate_dict(c, i, j, k, mf, a1, a2, n):
  d = {}
  d["n_estimators"] = n
  d["criterion"] = c
  d["max_depth"] = i 
  d["min_samples_split"] = j
  d["min_samples_leaf"] = k
  d["max_features"] = mf
  d["test_acc"] = a1
  d["train_acc"] = a2
  diff = a2-a1
  d["diff"] = diff
  return d

# %%
cr_list=['entropy', 'gini']
# sp_list=["best", "random"]
msl_list=[5,10,15,30]
mss_list=[5,10,15,30]
maxd_list=[3,5,10,15,20]
mf_list=["auto", "sqrt", "log2",None]
n_estimators_list = [50, 100, 150, 200]
result=[]

for ne in n_estimators_list:
  # for s in range(0,42):
    # for mln in range(2,5):
  for mf in range(len(mf_list)):
    for msl in msl_list:
      for mss in mss_list:
              # for sp in range(len(sp_list)):
        for cr in range(len(cr_list)):
                  # for jk in range(0,3):
          for i in maxd_list:
                      # decision_tree = AdaBoostClassifier(DecisionTreeClassifier(max_leaf_nodes=mln,max_features=mf_list[mf],min_samples_leaf=msl,min_samples_split=mss, splitter=sp_list[sp],criterion=cr_list[cr], random_state=jk, max_depth=i),n_estimators=ne, random_state=s ) #criterion="entropy",
                      # decision_tree = DecisionTreeClassifier(max_leaf_nodes=mln,max_features=mf_list[mf],min_samples_leaf=msl,min_samples_split=mss, splitter=sp_list[sp],criterion=cr_list[cr], random_state=jk, max_depth=i)
            decision_tree = RandomForestClassifier(max_features=mf_list[mf],min_samples_leaf=msl,min_samples_split=mss, criterion=cr_list[cr], max_depth=i, n_estimators=ne)
            decisiontree = decision_tree.fit(c_train,v_train)
            train_pred = decisiontree.predict(c_train)
            gff = classification_report(v_train, train_pred, output_dict=True)
            train_ac = (float)(gff['accuracy'])
            myy_pred = decisiontree.predict(c_test)
            gf = classification_report(v_test,myy_pred, output_dict=True)
            ac = (float)(gf['accuracy'])
            di = populate_dict(cr_list[cr], i, mss, msl, mf_list[mf], ac, train_ac, ne)
            result.append(di)

# %% [markdown]
# <b>Note that the accuracy on the test set will be considered and brownie points for not overfitting the model in the process</b>

# %%
sorted(result, key=lambda d : d["diff"], reverse=True)
# Out:
# [{'criterion': 'entropy',
#   'diff': 0.1024951486547998,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.1024951486547998,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.0998478713974269,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.9020866773675762},
#  {'criterion': 'gini',
#   'diff': 0.09980594619199357,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.09980594619199357,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.09980594619199357,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.09928487578160561,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8940609951845907},
#  {'criterion': 'entropy',
#   'diff': 0.09876380537121776,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.09820080975539647,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8892455858747994},
#  {'criterion': 'gini',
#   'diff': 0.09820080975539647,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8892455858747994},
#  {'criterion': 'gini',
#   'diff': 0.09820080975539647,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8892455858747994},
#  {'criterion': 'entropy',
#   'diff': 0.09767973934500851,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.09767973934500851,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.09767973934500851,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.09767973934500851,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'entropy',
#   'diff': 0.09715866893462066,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8956661316211878},
#  {'criterion': 'gini',
#   'diff': 0.09607460290841141,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'entropy',
#   'diff': 0.09607460290841141,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.09607460290841141,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.09551160729259,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7873134328358209,
#   'train_acc': 0.8828250401284109},
#  {'criterion': 'entropy',
#   'diff': 0.0950324620876356,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'gini',
#   'diff': 0.09446946647181431,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8892455858747994},
#  {'criterion': 'entropy',
#   'diff': 0.09446946647181431,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8892455858747994},
#  {'criterion': 'entropy',
#   'diff': 0.09394839606142646,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'entropy',
#   'diff': 0.09394839606142646,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'entropy',
#   'diff': 0.09394839606142646,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.09394839606142646,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.0934273256510385,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8956661316211878},
#  {'criterion': 'entropy',
#   'diff': 0.09338540044560506,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.884430176565008},
#  {'criterion': 'gini',
#   'diff': 0.0928643300352171,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8876404494382022},
#  {'criterion': 'gini',
#   'diff': 0.09234325962482937,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.09182218921444141,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8940609951845907},
#  {'criterion': 'entropy',
#   'diff': 0.09182218921444141,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8940609951845907},
#  {'criterion': 'entropy',
#   'diff': 0.09182218921444141,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8940609951845907},
#  {'criterion': 'gini',
#   'diff': 0.09130111880405356,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.09130111880405356,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'gini',
#   'diff': 0.09125919359862,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8860353130016051},
#  {'criterion': 'gini',
#   'diff': 0.09073812318823227,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8892455858747994},
#  {'criterion': 'gini',
#   'diff': 0.09021705277784431,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.09017512757241086,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.8812199036918138},
#  {'criterion': 'gini',
#   'diff': 0.0896540571620229,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.884430176565008},
#  {'criterion': 'gini',
#   'diff': 0.08917491195706861,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.898876404494382},
#  {'criterion': 'entropy',
#   'diff': 0.08917491195706861,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.898876404494382},
#  {'criterion': 'entropy',
#   'diff': 0.08809084593085936,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8940609951845907},
#  {'criterion': 'entropy',
#   'diff': 0.08809084593085936,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8940609951845907},
#  {'criterion': 'entropy',
#   'diff': 0.08756977552047152,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.08756977552047152,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.08756977552047152,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.08756977552047152,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'entropy',
#   'diff': 0.08756977552047152,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'gini',
#   'diff': 0.08752785031503796,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8860353130016051},
#  {'criterion': 'entropy',
#   'diff': 0.08752785031503796,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8860353130016051},
#  {'criterion': 'entropy',
#   'diff': 0.08704870511008356,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.9004815409309791},
#  {'criterion': 'entropy',
#   'diff': 0.08648570949426226,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.08648570949426226,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.08592271387844086,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.884430176565008},
#  {'criterion': 'gini',
#   'diff': 0.0854016434680529,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8876404494382022},
#  {'criterion': 'gini',
#   'diff': 0.08488057305766517,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'entropy',
#   'diff': 0.08488057305766517,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.08431757744184376,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8828250401284109},
#  {'criterion': 'entropy',
#   'diff': 0.08383843223688936,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'gini',
#   'diff': 0.08323351141563451,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'entropy',
#   'diff': 0.08275436621068022,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8924558587479936},
#  {'criterion': 'gini',
#   'diff': 0.08271244100524666,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8812199036918138},
#  {'criterion': 'gini',
#   'diff': 0.0821913705948587,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.884430176565008},
#  {'criterion': 'gini',
#   'diff': 0.0821913705948587,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.884430176565008},
#  {'criterion': 'gini',
#   'diff': 0.0805862341582616,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8828250401284109},
#  {'criterion': 'gini',
#   'diff': 0.0805862341582616,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8828250401284109},
#  {'criterion': 'entropy',
#   'diff': 0.08010708895330731,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8972712680577849},
#  {'criterion': 'gini',
#   'diff': 0.08006516374787376,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8860353130016051},
#  {'criterion': 'gini',
#   'diff': 0.07846002731127666,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.884430176565008},
#  {'criterion': 'entropy',
#   'diff': 0.07793895690088881,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8876404494382022},
#  {'criterion': 'entropy',
#   'diff': 0.07793895690088881,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8876404494382022},
#  {'criterion': 'gini',
#   'diff': 0.07741788649050096,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'gini',
#   'diff': 0.07737596128506741,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8796147672552167},
#  {'criterion': 'gini',
#   'diff': 0.07577082484847031,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'entropy',
#   'diff': 0.07468675882226117,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8731942215088283},
#  {'criterion': 'entropy',
#   'diff': 0.07420761361730666,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8876404494382022},
#  {'criterion': 'entropy',
#   'diff': 0.07416568841187321,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8764044943820225},
#  {'criterion': 'gini',
#   'diff': 0.07416568841187321,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8764044943820225},
#  {'criterion': 'entropy',
#   'diff': 0.07368654320691892,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8908507223113965},
#  {'criterion': 'entropy',
#   'diff': 0.07364461800148536,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8796147672552167},
#  {'criterion': 'entropy',
#   'diff': 0.07364461800148536,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8796147672552167},
#  {'criterion': 'entropy',
#   'diff': 0.07308162238566396,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8715890850722311},
#  {'criterion': 'gini',
#   'diff': 0.07260247718070956,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8860353130016051},
#  {'criterion': 'gini',
#   'diff': 0.07203948156488826,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'gini',
#   'diff': 0.0719975563594547,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.07151841115450042,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8812199036918138},
#  {'criterion': 'gini',
#   'diff': 0.07147648594906686,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'gini',
#   'diff': 0.0693502791020818,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8715890850722311},
#  {'criterion': 'gini',
#   'diff': 0.0693502791020818,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8715890850722311},
#  {'criterion': 'entropy',
#   'diff': 0.06830813828130622,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'gini',
#   'diff': 0.06830813828130622,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'entropy',
#   'diff': 0.06830813828130622,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'entropy',
#   'diff': 0.06826621307587266,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.06826621307587266,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'entropy',
#   'diff': 0.06826621307587266,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.0677451426654847,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'gini',
#   'diff': 0.06722407225509697,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8731942215088283},
#  {'criterion': 'entropy',
#   'diff': 0.06670300184470912,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8764044943820225},
#  {'criterion': 'entropy',
#   'diff': 0.0661400062288876,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.06509786540811202,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8747993579454254},
#  {'criterion': 'gini',
#   'diff': 0.0645348697922905,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.0645348697922905,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.0645348697922905,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.0645348697922905,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.06401379938190266,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'entropy',
#   'diff': 0.06397187417646921,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.8587479935794543},
#  {'criterion': 'entropy',
#   'diff': 0.06349272897151492,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8731942215088283},
#  {'criterion': 'gini',
#   'diff': 0.06345080376608137,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'gini',
#   'diff': 0.0629297333556934,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.0629297333556934,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.0629297333556934,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.06240866294530556,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'gini',
#   'diff': 0.06240866294530556,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.06132459691909631,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.06132459691909631,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'entropy',
#   'diff': 0.06084545171414202,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8780096308186196},
#  {'criterion': 'entropy',
#   'diff': 0.06080352650870846,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'entropy',
#   'diff': 0.06080352650870846,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'entropy',
#   'diff': 0.060282456098320614,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'entropy',
#   'diff': 0.060282456098320614,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'gini',
#   'diff': 0.060282456098320614,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'gini',
#   'diff': 0.060282456098320614,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'entropy',
#   'diff': 0.06024053089288717,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8587479935794543},
#  {'criterion': 'entropy',
#   'diff': 0.059761385687932767,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8731942215088283},
#  {'criterion': 'entropy',
#   'diff': 0.05971946048249921,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'entropy',
#   'diff': 0.05924031527754492,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8764044943820225},
#  {'criterion': 'gini',
#   'diff': 0.05919839007211136,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'entropy',
#   'diff': 0.05919839007211136,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05919839007211136,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'entropy',
#   'diff': 0.05919839007211136,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.058677319661723515,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.058677319661723515,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'gini',
#   'diff': 0.058677319661723515,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.05811432404590211,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'entropy',
#   'diff': 0.05811432404590211,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'entropy',
#   'diff': 0.05759325363551426,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05759325363551426,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05759325363551426,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'entropy',
#   'diff': 0.05759325363551426,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05759325363551426,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'entropy',
#   'diff': 0.057072183225126416,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.057072183225126416,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'entropy',
#   'diff': 0.057072183225126416,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.057072183225126416,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.057072183225126416,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.05655111281473846,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'gini',
#   'diff': 0.05655111281473846,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.869983948635634},
#  {'criterion': 'entropy',
#   'diff': 0.05650918760930501,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8587479935794543},
#  {'criterion': 'entropy',
#   'diff': 0.055988117198917164,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'gini',
#   'diff': 0.055988117198917164,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'entropy',
#   'diff': 0.055988117198917164,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'gini',
#   'diff': 0.055988117198917164,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'gini',
#   'diff': 0.055988117198917164,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'gini',
#   'diff': 0.055988117198917164,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8619582664526485},
#  {'criterion': 'entropy',
#   'diff': 0.05546704678852932,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05546704678852932,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'entropy',
#   'diff': 0.05546704678852932,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05546704678852932,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'entropy',
#   'diff': 0.05546704678852932,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05546704678852932,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05546704678852932,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'entropy',
#   'diff': 0.05546704678852932,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05546704678852932,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05546704678852932,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'entropy',
#   'diff': 0.05546704678852932,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8651685393258427},
#  {'criterion': 'gini',
#   'diff': 0.05494597637814136,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.05494597637814136,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.05494597637814136,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8683788121990369},
#  {'criterion': 'entropy',
#   'diff': 0.0549040511727078,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8571428571428571},
#  {'criterion': 'entropy',
#   'diff': 0.0549040511727078,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8571428571428571},
#  {'criterion': 'entropy',
#   'diff': 0.0549040511727078,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8571428571428571},
#  {'criterion': 'entropy',
#   'diff': 0.054382980762320066,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'gini',
#   'diff': 0.054382980762320066,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'entropy',
#   'diff': 0.054382980762320066,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'entropy',
#   'diff': 0.054382980762320066,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'gini',
#   'diff': 0.054382980762320066,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'entropy',
#   'diff': 0.054382980762320066,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8603531300160514},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'entropy',
#   'diff': 0.05386191035193222,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'entropy',
#   'diff': 0.05386191035193222,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'gini',
#   'diff': 0.05386191035193222,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8635634028892456},
#  {'criterion': 'entropy',
#   'diff': 0.05381998514649866,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.8523274478330658},
#  {'criterion': 'entropy',
#   'diff': 0.05334083994154426,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.05334083994154426,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'entropy',
#   'diff': 0.05334083994154426,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'gini',
#   'diff': 0.05334083994154426,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8667736757624398},
#  {'criterion': 'entropy',
#   'diff': 0.0532989147361107,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.85553772070626},
#  {'criterion': 'entropy',
#   'diff': 0.0532989147361107,
#   'max_depth': 5,
#   'max_features': None,
# ...
#   'diff': 0.029784863802975514,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'entropy',
#   'diff': 0.029784863802975514,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'gini',
#   'diff': 0.029784863802975514,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'entropy',
#   'diff': 0.029784863802975514,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'gini',
#   'diff': 0.029784863802975514,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'entropy',
#   'diff': 0.029784863802975514,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'gini',
#   'diff': 0.029784863802975514,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'gini',
#   'diff': 0.029784863802975514,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'gini',
#   'diff': 0.029784863802975514,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'entropy',
#   'diff': 0.029784863802975514,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'gini',
#   'diff': 0.029784863802975514,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8394863563402889},
#  {'criterion': 'entropy',
#   'diff': 0.029305718598021113,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8539325842696629},
#  {'criterion': 'entropy',
#   'diff': 0.029305718598021113,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8539325842696629},
#  {'criterion': 'gini',
#   'diff': 0.029305718598021113,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8539325842696629},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'entropy',
#   'diff': 0.029263793392587556,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'entropy',
#   'diff': 0.029263793392587556,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'entropy',
#   'diff': 0.029263793392587556,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'entropy',
#   'diff': 0.029263793392587556,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'entropy',
#   'diff': 0.029263793392587556,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'entropy',
#   'diff': 0.029263793392587556,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.029263793392587556,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8426966292134831},
#  {'criterion': 'gini',
#   'diff': 0.02922186818715411,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.8314606741573034},
#  {'criterion': 'gini',
#   'diff': 0.02909609257085355,
#   'max_depth': 1,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7686567164179104,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'entropy',
#   'diff': 0.02909609257085355,
#   'max_depth': 1,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.7686567164179104,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'gini',
#   'diff': 0.02874272298219982,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8459069020866774},
#  {'criterion': 'entropy',
#   'diff': 0.028700797776766263,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8346709470304976},
#  {'criterion': 'entropy',
#   'diff': 0.028700797776766263,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8346709470304976},
#  {'criterion': 'gini',
#   'diff': 0.028700797776766263,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8346709470304976},
#  {'criterion': 'entropy',
#   'diff': 0.028700797776766263,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8346709470304976},
#  {'criterion': 'gini',
#   'diff': 0.028700797776766263,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8346709470304976},
#  {'criterion': 'gini',
#   'diff': 0.028700797776766263,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8346709470304976},
#  ...]

# %%
sorted(result, key=lambda d : d["diff"], reverse=False)
# Out:
# [{'criterion': 'gini',
#   'diff': -0.026915981888311236,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.02687405668287779,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.026352986272489942,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.024268704630938442,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.7817014446227929},
#  {'criterion': 'entropy',
#   'diff': -0.023142713399295745,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.023142713399295745,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.023100788193862187,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.832089552238806,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.022663568194341344,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.022663568194341344,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.022663568194341344,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.021537576962698535,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.021537576962698535,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.021537576962698535,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'entropy',
#   'diff': -0.02049543614192284,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7929373996789727},
#  {'criterion': 'gini',
#   'diff': -0.01989051532066799,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.832089552238806,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'gini',
#   'diff': -0.019453295321147035,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.01941137011571359,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.01936944491028003,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8283582089552238,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.0189322249107593,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.01889029970532574,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.01889029970532574,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.01889029970532574,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'gini',
#   'diff': -0.01889029970532574,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.01780623367911638,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.01780623367911638,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.01780623367911638,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.01780623367911638,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.01780623367911638,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'entropy',
#   'diff': -0.01732708847416209,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'gini',
#   'diff': -0.01732708847416209,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'entropy',
#   'diff': -0.017285163268728643,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7961476725521669},
#  {'criterion': 'gini',
#   'diff': -0.01672216765290724,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'entropy',
#   'diff': -0.01672216765290724,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.01620109724251928,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8009630818619583},
#  {'criterion': 'entropy',
#   'diff': -0.01620109724251928,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8009630818619583},
#  {'criterion': 'gini',
#   'diff': -0.01572195203756499,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.01572195203756499,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.01572195203756499,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.01572195203756499,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.015680026832131544,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.015680026832131544,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.015680026832131544,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.015680026832131544,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'entropy',
#   'diff': -0.015680026832131544,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.015680026832131544,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'entropy',
#   'diff': -0.015638101626697987,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'gini',
#   'diff': -0.015200881627177143,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.015200881627177143,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.015158956421743586,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.015158956421743586,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.015158956421743586,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.015158956421743586,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'gini',
#   'diff': -0.015158956421743586,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7945425361155698},
#  {'criterion': 'entropy',
#   'diff': -0.014637886011355739,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.7913322632423756},
#  {'criterion': 'gini',
#   'diff': -0.014595960805922181,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.014595960805922181,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.014116815600967891,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'entropy',
#   'diff': -0.014116815600967891,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'gini',
#   'diff': -0.014116815600967891,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'gini',
#   'diff': -0.014116815600967891,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'entropy',
#   'diff': -0.014116815600967891,
#   'max_depth': 15,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'entropy',
#   'diff': -0.014074890395534334,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.014074890395534334,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'entropy',
#   'diff': -0.014074890395534334,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.014074890395534334,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.014074890395534334,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'gini',
#   'diff': -0.013595745190579933,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'gini',
#   'diff': -0.013595745190579933,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'gini',
#   'diff': -0.013595745190579933,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'gini',
#   'diff': -0.013595745190579933,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'gini',
#   'diff': -0.013553819985146487,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7961476725521669},
#  {'criterion': 'gini',
#   'diff': -0.013553819985146487,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7961476725521669},
#  {'criterion': 'gini',
#   'diff': -0.013553819985146487,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7961476725521669},
#  {'criterion': 'entropy',
#   'diff': -0.013553819985146487,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7961476725521669},
#  {'criterion': 'gini',
#   'diff': -0.01351189477971304,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8073836276083467},
#  {'criterion': 'entropy',
#   'diff': -0.01351189477971304,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8073836276083467},
#  {'criterion': 'entropy',
#   'diff': -0.01351189477971304,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8073836276083467},
#  {'criterion': 'gini',
#   'diff': -0.013074674780192197,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.7817014446227929},
#  {'criterion': 'gini',
#   'diff': -0.01303274957475864,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.7929373996789727},
#  {'criterion': 'entropy',
#   'diff': -0.01303274957475864,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.7929373996789727},
#  {'criterion': 'gini',
#   'diff': -0.012990824369325082,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.012990824369325082,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.012990824369325082,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'entropy',
#   'diff': -0.012990824369325082,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.012990824369325082,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.012948899163891525,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8283582089552238,
#   'train_acc': 0.8154093097913323},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'entropy',
#   'diff': -0.012553604369804239,
#   'max_depth': 1,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7784911717495987},
#  {'criterion': 'gini',
#   'diff': -0.012511679164370793,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7897271268057785},
#  {'criterion': 'entropy',
#   'diff': -0.012469753958937235,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8009630818619583},
#  {'criterion': 'gini',
#   'diff': -0.012469753958937235,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8009630818619583},
#  {'criterion': 'entropy',
#   'diff': -0.011990608753982834,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.011990608753982834,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.011990608753982834,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.011990608753982834,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.011990608753982834,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.011948683548549388,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.011906758343115942,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.011469538343595098,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011469538343595098,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.011469538343595098,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011469538343595098,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011469538343595098,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011469538343595098,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011469538343595098,
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.011469538343595098,
#   'max_depth': 20,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.011469538343595098,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.011469538343595098,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'entropy',
#   'diff': -0.011469538343595098,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011469538343595098,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.78330658105939},
#  {'criterion': 'gini',
#   'diff': -0.011385687932727984,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8057784911717496},
#  {'criterion': 'gini',
#   'diff': -0.011385687932727984,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.8057784911717496},
#  {'criterion': 'gini',
#   'diff': -0.011343762727294426,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8283582089552238,
#   'train_acc': 0.8170144462279294},
#  {'criterion': 'gini',
#   'diff': -0.010906542727773694,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.7913322632423756},
#  {'criterion': 'gini',
#   'diff': -0.010864617522340136,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.010864617522340136,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.010864617522340136,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.010864617522340136,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.010864617522340136,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.010864617522340136,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.010864617522340136,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.010864617522340136,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.010864617522340136,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.010864617522340136,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.01082269231690658,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8138041733547352},
#  {'criterion': 'gini',
#   'diff': -0.01082269231690658,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8138041733547352},
#  {'criterion': 'entropy',
#   'diff': -0.01082269231690658,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8138041733547352},
#  {'criterion': 'gini',
#   'diff': -0.010385472317385736,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'gini',
#   'diff': -0.010385472317385736,
#   'max_depth': 10,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'entropy',
#   'diff': -0.010385472317385736,
#   'max_depth': 10,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7985074626865671,
#   'train_acc': 0.7881219903691814},
#  {'criterion': 'entropy',
#   'diff': -0.010343547111952178,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'entropy',
#   'diff': -0.010343547111952178,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.7993579454253612},
#  {'criterion': 'entropy',
#   'diff': -0.010301621906518843,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8105939004815409},
#  {'criterion': 'gini',
#   'diff': -0.010301621906518843,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8105939004815409},
#  {'criterion': 'entropy',
#   'diff': -0.009864401906997888,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.7849117174959872},
#  {'criterion': 'gini',
# ...
#   'diff': -0.00604920821254884,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8073836276083467},
#  {'criterion': 'gini',
#   'diff': -0.00604920821254884,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8073836276083467},
#  {'criterion': 'entropy',
#   'diff': -0.006007283007115283,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8186195826645265},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'entropy',
#   'diff': -0.005528137802160882,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.005528137802160882,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8041733547351525},
#  {'criterion': 'gini',
#   'diff': -0.0054862125967274356,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8154093097913323},
#  {'criterion': 'gini',
#   'diff': -0.0054862125967274356,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8154093097913323},
#  {'criterion': 'entropy',
#   'diff': -0.0054862125967274356,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8154093097913323},
#  {'criterion': 'gini',
#   'diff': -0.0054862125967274356,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8154093097913323},
#  {'criterion': 'entropy',
#   'diff': -0.005048992597206592,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7947761194029851,
#   'train_acc': 0.7897271268057785},
#  {'criterion': 'entropy',
#   'diff': -0.005007067391773035,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8009630818619583},
#  {'criterion': 'gini',
#   'diff': -0.005007067391773035,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8009630818619583},
#  {'criterion': 'gini',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'gini',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'entropy',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'entropy',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'entropy',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'gini',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'entropy',
#   'diff': -0.004965142186339588,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 200,
#   'test_acc': 0.8171641791044776,
#   'train_acc': 0.812199036918138},
#  {'criterion': 'entropy',
#   'diff': -0.004527922186818634,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.004527922186818634,
#   'max_depth': 5,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.004527922186818634,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.004527922186818634,
#   'max_depth': 3,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.004527922186818634,
#   'max_depth': 5,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.004527922186818634,
#   'max_depth': 15,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'entropy',
#   'diff': -0.004527922186818634,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.004527922186818634,
#   'max_depth': 15,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.004527922186818634,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 150,
#   'test_acc': 0.7910447761194029,
#   'train_acc': 0.7865168539325843},
#  {'criterion': 'gini',
#   'diff': -0.0044859969813852985,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'gini',
#   'diff': -0.0044859969813852985,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8022388059701493,
#   'train_acc': 0.797752808988764},
#  {'criterion': 'entropy',
#   'diff': -0.004444071775951741,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.004444071775951741,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.004444071775951741,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'gini',
#   'diff': -0.004444071775951741,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.004444071775951741,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 5,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8134328358208955,
#   'train_acc': 0.8089887640449438},
#  {'criterion': 'entropy',
#   'diff': -0.004402146570518184,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8202247191011236},
#  {'criterion': 'gini',
#   'diff': -0.004402146570518184,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8202247191011236},
#  {'criterion': 'entropy',
#   'diff': -0.004402146570518184,
#   'max_depth': 10,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8246268656716418,
#   'train_acc': 0.8202247191011236},
#  {'criterion': 'entropy',
#   'diff': -0.003923001365563783,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8057784911717496},
#  {'criterion': 'gini',
#   'diff': -0.003923001365563783,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 50,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8057784911717496},
#  {'criterion': 'gini',
#   'diff': -0.003923001365563783,
#   'max_depth': 3,
#   'max_features': 'log2',
#   'min_samples_leaf': 10,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8097014925373134,
#   'train_acc': 0.8057784911717496},
#  {'criterion': 'gini',
#   'diff': -0.0038810761601303367,
#   'max_depth': 20,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8170144462279294},
#  {'criterion': 'entropy',
#   'diff': -0.0038810761601303367,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 10,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8170144462279294},
#  {'criterion': 'entropy',
#   'diff': -0.0038810761601303367,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 15,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8170144462279294},
#  {'criterion': 'entropy',
#   'diff': -0.0038810761601303367,
#   'max_depth': 5,
#   'max_features': 'log2',
#   'min_samples_leaf': 15,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8208955223880597,
#   'train_acc': 0.8170144462279294},
#  {'criterion': 'gini',
#   'diff': -0.003401930955175936,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 50,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 3,
#   'max_features': 'auto',
#   'min_samples_leaf': 5,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.003401930955175936,
#   'max_depth': 3,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 100,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 20,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 10,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.003401930955175936,
#   'max_depth': 15,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 15,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'gini',
#   'diff': -0.003401930955175936,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 30,
#   'n_estimators': 150,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 5,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  {'criterion': 'entropy',
#   'diff': -0.003401930955175936,
#   'max_depth': 10,
#   'max_features': None,
#   'min_samples_leaf': 30,
#   'min_samples_split': 5,
#   'n_estimators': 200,
#   'test_acc': 0.8059701492537313,
#   'train_acc': 0.8025682182985554},
#  ...]

# %% [markdown]
# <b>print the test accuracy and train accuracy here</b>

# %%
print( 'Random Forest')
print(  {'criterion': 'gini',
  'diff': 0.021843032030856913,
  'max_depth': 20,
  'max_features': 'sqrt',
  'min_samples_leaf': 5,
  'min_samples_split': 30,
  'n_estimators': 50,
  'test_acc': 0.832089552238806,
  'train_acc': 0.8539325842696629} )
# Out:
# Random Forest
# {'criterion': 'gini', 'diff': 0.021843032030856913, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30, 'n_estimators': 50, 'test_acc': 0.832089552238806, 'train_acc': 0.8539325842696629}

# %% [markdown]
# End
